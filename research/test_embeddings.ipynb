# %%
import sys
sys.path.append('..')

# %%
from services.embeddings_gigachat import MyGigaChatEmbeddingsCached

# %%
embeddings = MyGigaChatEmbeddingsCached

# %%
embeddings.embed_query("Привет, как дела?")
# Out:
# [0.9669821262359619,
#  -0.41290876269340515,
#  -1.1595122814178467,
#  -1.5577375888824463,
#  0.7547680139541626,
#  -0.4682423174381256,
#  -0.16225382685661316,
#  2.8807103633880615,
#  1.4592961072921753,
#  -0.8305526971817017,
#  0.8728989362716675,
#  0.719291090965271,
#  -1.8815159797668457,
#  -0.10361404716968536,
#  -0.618635892868042,
#  -1.104430913925171,
#  0.5250115990638733,
#  0.36742788553237915,
#  0.3383556306362152,
#  -0.41027307510375977,
#  0.5608195662498474,
#  -0.5225406885147095,
#  -0.1270817667245865,
#  -1.0311517715454102,
#  0.5574405193328857,
#  -0.2974158525466919,
#  -1.481337070465088,
#  -1.1901319026947021,
#  -0.6044301986694336,
#  -1.2315597534179688,
#  -0.3487401306629181,
#  0.8704729676246643,
#  -1.6974583864212036,
#  -0.665860652923584,
#  -0.8716408014297485,
#  1.1098456382751465,
#  0.8989055156707764,
#  1.005108118057251,
#  -0.8924038410186768,
#  0.7767241597175598,
#  -0.6487671136856079,
#  1.5164583921432495,
# ...
